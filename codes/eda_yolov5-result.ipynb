# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from tqdm.notebook import tqdm
from multiprocessing import cpu_count

import torch
import imageio
import sys
import os
from PIL import Image
from IPython.display import display, Markdown, Latex

#print(f'python version: {sys.version}')
#print(f'torch version: {torch.__version__}')

# %% [markdown]
# # Test

# %%
train_df = pd.read_csv('../input/petfinder-pawpularity-score/train.csv', index_col='Id')

# %%
train_df
# Out:
#                                   Subject Focus  Eyes  Face  Near  Action  \
# Id
# 0007de18844b0dbbb5e1f607da0606e0              0     1     1     1       0
# 0009c66b9439883ba2750fb825e1d7db              0     1     1     0       0
# 0013fd999caf9a3efe1352ca1b0d937e              0     1     1     1       0
# 0018df346ac9c1d8413cfcc888ca8246              0     1     1     1       0
# 001dc955e10590d3ca4673f034feeef2              0     0     0     1       0
# ...                                         ...   ...   ...   ...     ...
# ffbfa0383c34dc513c95560d6e1fdb57              0     0     0     1       0
# ffcc8532d76436fc79e50eb2e5238e45              0     1     1     1       0
# ffdf2e8673a1da6fb80342fa3b119a20              0     1     1     1       0
# fff19e2ce11718548fa1c5d039a5192a              0     1     1     1       0
# fff8e47c766799c9e12f3cb3d66ad228              0     1     1     1       0
#
#                                   Accessory  Group  Collage  Human  Occlusion  \
# Id
# 0007de18844b0dbbb5e1f607da0606e0          0      1        0      0          0
# 0009c66b9439883ba2750fb825e1d7db          0      0        0      0          0
# 0013fd999caf9a3efe1352ca1b0d937e          0      0        0      1          1
# 0018df346ac9c1d8413cfcc888ca8246          0      0        0      0          0
# 001dc955e10590d3ca4673f034feeef2          0      1        0      0          0
# ...                                     ...    ...      ...    ...        ...
# ffbfa0383c34dc513c95560d6e1fdb57          0      0        0      0          0
# ffcc8532d76436fc79e50eb2e5238e45          0      0        0      0          0
# ffdf2e8673a1da6fb80342fa3b119a20          0      0        0      1          1
# fff19e2ce11718548fa1c5d039a5192a          0      0        0      1          0
# fff8e47c766799c9e12f3cb3d66ad228          0      0        0      0          0
#
#                                   Info  Blur  Pawpularity
# Id
# 0007de18844b0dbbb5e1f607da0606e0     0     0           63
# 0009c66b9439883ba2750fb825e1d7db     0     0           42
# 0013fd999caf9a3efe1352ca1b0d937e     0     0           28
# 0018df346ac9c1d8413cfcc888ca8246     0     0           15
# 001dc955e10590d3ca4673f034feeef2     0     0           72
# ...                                ...   ...          ...
# ffbfa0383c34dc513c95560d6e1fdb57     0     1           15
# ffcc8532d76436fc79e50eb2e5238e45     0     0           70
# ffdf2e8673a1da6fb80342fa3b119a20     0     0           20
# fff19e2ce11718548fa1c5d039a5192a     0     0           20
# fff8e47c766799c9e12f3cb3d66ad228     0     0           30
#
# [9912 rows x 13 columns]

# %% [markdown]
# # Train

# %% [markdown]
# Use the train DataFrame with a cat/dog classification from [this](https://www.kaggle.com/markwijkhuizen/petfinder-eda-yolov5-obj-detection-tfrecords) notebook.

# %%
# Train DataFrame with YOLOV5 info
train = pd.read_pickle('/kaggle/input/petfinder-yolov5-kfold-tfrecords/train.pkl')

# %%
display(train.head())
# Out:
#                                  Id  Subject Focus  Eyes  Face  Near  Action  \
# 0  0007de18844b0dbbb5e1f607da0606e0              0     1     1     1       0
# 1  0009c66b9439883ba2750fb825e1d7db              0     1     1     0       0
# 2  0013fd999caf9a3efe1352ca1b0d937e              0     1     1     1       0
# 3  0018df346ac9c1d8413cfcc888ca8246              0     1     1     1       0
# 4  001dc955e10590d3ca4673f034feeef2              0     0     0     1       0
#
#    Accessory  Group  Collage  Human  ...  Pawpularity  \
# 0          0      1        0      0  ...           63
# 1          0      0        0      0  ...           42
# 2          0      0        0      1  ...           28
# 3          0      0        0      0  ...           15
# 4          0      1        0      0  ...           72
#
#                                            file_path  n_pets  label  \
# 0  /kaggle/input/petfinder-pawpularity-score/trai...       3    dog
# 1  /kaggle/input/petfinder-pawpularity-score/trai...       1    cat
# 2  /kaggle/input/petfinder-pawpularity-score/trai...       1    dog
# 3  /kaggle/input/petfinder-pawpularity-score/trai...       1    dog
# 4  /kaggle/input/petfinder-pawpularity-score/trai...       2    dog
#
#                                               coords      x_min       x_max  \
# 0  [(120.58594, 114.75, 325.125, 474.75), (202.21...  202.21875   32.062500
# 1      [(649.03125, 198.13593, 886.0687, 476.49374)]  649.03125  886.068726
# 2                [(110.4375, 63.75, 575.25, 684.75)]  110.43750  575.250000
# 3        [(0.5625, 217.40625, 404.15625, 559.96875)]    0.56250  404.000000
# 4  [(51.1875, 218.625, 513.0, 651.375), (142.875,...  142.87500  513.000000
#
#         y_min       y_max  pet_ratio
# 0  114.750000  229.218750   0.346914
# 1  198.135925  476.493744   0.082485
# 2   63.750000  684.750000   0.417773
# 3  217.406250  559.968750   0.473827
# 4  218.625000  377.625000   0.558559
#
# [5 rows x 23 columns]

# %%
display(train.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9912 entries, 0 to 9911
# Data columns (total 23 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             9912 non-null   string
#  1   Subject Focus  9912 non-null   uint8
#  2   Eyes           9912 non-null   uint8
#  3   Face           9912 non-null   uint8
#  4   Near           9912 non-null   uint8
#  5   Action         9912 non-null   uint8
#  6   Accessory      9912 non-null   uint8
#  7   Group          9912 non-null   uint8
#  8   Collage        9912 non-null   uint8
#  9   Human          9912 non-null   uint8
#  10  Occlusion      9912 non-null   uint8
#  11  Info           9912 non-null   uint8
#  12  Blur           9912 non-null   uint8
#  13  Pawpularity    9912 non-null   uint8
#  14  file_path      9912 non-null   object
#  15  n_pets         9912 non-null   int64
#  16  label          9912 non-null   object
#  17  coords         9912 non-null   object
#  18  x_min          9912 non-null   float64
#  19  x_max          9912 non-null   float64
#  20  y_min          9912 non-null   float64
#  21  y_max          9912 non-null   float64
#  22  pet_ratio      9912 non-null   float64
# dtypes: float64(5), int64(1), object(3), string(1), uint8(13)
# memory usage: 900.3+ KB
# None

# %%
train.to_csv('yolotrain.csv')

# %% [markdown]
# # Cat/Dog/Unknown Mean Pawpularity Scores

# %%
# Cat/Dog/Unknown distribution
display(train['label'].value_counts(normalize=True).to_frame() * 100)
# Out:
#              label
# cat      53.379742
# dog      46.337772
# unknown   0.282486

# %%
count_df = train.groupby(['label'])['label'].count()
count_df = count_df.to_frame()
count_df = count_df.rename(columns={"label": "label", "label": "counts"})
count_df = count_df.reset_index()
count_df
# Out:
#      label  counts
# 0      cat    5291
# 1      dog    4593
# 2  unknown      28

# %% [markdown]
# # Pie Graph

# %%
import plotly.graph_objects as go

labels = count_df['label'] 
#values = [4500, 2500, 1053, 500]

# Use `hole` to create a donut-like pie chart
fig = go.Figure(data=[go.Pie(labels=count_df['label'] , 
                             values=count_df['counts'], 
                             hole=.70)])
fig.update_layout(
    #autosize=False,
    width=600,
    height=400,
    title="Pie Graph for Cats and Dogs Counts"
)

fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.4.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="47c84564-f983-41ff-9060-54c96e906fa2" class="plotly-graph-div" style="height:400px; width:600px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("47c84564-f983-41ff-9060-54c96e906fa2")) {                    Plotly.newPlot(                        "47c84564-f983-41ff-9060-54c96e906fa2",                        [{"hole":0.7,"labels":["cat","dog","unknown"],"type":"pie","values":[5291,4593,28]}],                        {"height":400,"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter3d"}],"scattercarpet":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scattercarpet"}],"scattergeo":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""} ...
#
# var gd = document.getElementById('47c84564-f983-41ff-9060-54c96e906fa2');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console

# %% [markdown]
# This next cell shows what this notebook is all about. Dogs have on average a Pawpularity score of 42.10, whereas cats only have an average Pawpularity score of 34.52.

# %%
# Mean Pawpularity scores per pet
DOG_MEAN = train.loc[train['label'] == 'dog', 'Pawpularity'].mean()
CAT_MEAN = train.loc[train['label'] == 'cat', 'Pawpularity'].mean()
GLOBAL_MEAN = train['Pawpularity'].mean()

# Dogs seem to be more Pawpular than cats on average
print(f'DOG_MEAN: {DOG_MEAN:.2f}, CAT_MEAN: {CAT_MEAN:.2f}, GLOBAL_MEAN: {GLOBAL_MEAN:.2f}')
# Out:
# DOG_MEAN: 42.10, CAT_MEAN: 34.52, GLOBAL_MEAN: 38.04

# %% [markdown]
# The next histogram clearly shows cats have a lower Pawpularity score. The most surprising observation is the large amount of dogs having a Pawpularity score of near 100.

# %%
# Plot Pawpularity distribution for cats and dogs
plt.figure(figsize=(10, 6))
plt.title('Pawpularity distribution for Cats and Dogs', size=24)
plt.axvline(DOG_MEAN, c='red', ls='-', lw=3, label='Dog Mean Pawpularity')
plt.axvline(CAT_MEAN, c='green', ls='-', lw=3, label='Cat Mean Pawpularity')
train.loc[train['label'] != 'unknown'].groupby('label')['Pawpularity'].plot(kind='hist', bins=32, alpha=0.50)
plt.legend(prop={'size': 16})
pass

# %%
train
# Out:
#                                     Id  Subject Focus  Eyes  Face  Near  \
# 0     0007de18844b0dbbb5e1f607da0606e0              0     1     1     1
# 1     0009c66b9439883ba2750fb825e1d7db              0     1     1     0
# 2     0013fd999caf9a3efe1352ca1b0d937e              0     1     1     1
# 3     0018df346ac9c1d8413cfcc888ca8246              0     1     1     1
# 4     001dc955e10590d3ca4673f034feeef2              0     0     0     1
# ...                                ...            ...   ...   ...   ...
# 9907  ffbfa0383c34dc513c95560d6e1fdb57              0     0     0     1
# 9908  ffcc8532d76436fc79e50eb2e5238e45              0     1     1     1
# 9909  ffdf2e8673a1da6fb80342fa3b119a20              0     1     1     1
# 9910  fff19e2ce11718548fa1c5d039a5192a              0     1     1     1
# 9911  fff8e47c766799c9e12f3cb3d66ad228              0     1     1     1
#
#       Action  Accessory  Group  Collage  Human  ...  Pawpularity  \
# 0          0          0      1        0      0  ...           63
# 1          0          0      0        0      0  ...           42
# 2          0          0      0        0      1  ...           28
# 3          0          0      0        0      0  ...           15
# 4          0          0      1        0      0  ...           72
# ...      ...        ...    ...      ...    ...  ...          ...
# 9907       0          0      0        0      0  ...           15
# 9908       0          0      0        0      0  ...           70
# 9909       0          0      0        0      1  ...           20
# 9910       0          0      0        0      1  ...           20
# 9911       0          0      0        0      0  ...           30
#
#                                               file_path  n_pets  label  \
# 0     /kaggle/input/petfinder-pawpularity-score/trai...       3    dog
# 1     /kaggle/input/petfinder-pawpularity-score/trai...       1    cat
# 2     /kaggle/input/petfinder-pawpularity-score/trai...       1    dog
# 3     /kaggle/input/petfinder-pawpularity-score/trai...       1    dog
# 4     /kaggle/input/petfinder-pawpularity-score/trai...       2    dog
# ...                                                 ...     ...    ...
# 9907  /kaggle/input/petfinder-pawpularity-score/trai...       1    cat
# 9908  /kaggle/input/petfinder-pawpularity-score/trai...       1    dog
# 9909  /kaggle/input/petfinder-pawpularity-score/trai...       1    cat
# 9910  /kaggle/input/petfinder-pawpularity-score/trai...       1    dog
# 9911  /kaggle/input/petfinder-pawpularity-score/trai...       1    dog
#
#                                                  coords      x_min  \
# 0     [(120.58594, 114.75, 325.125, 474.75), (202.21...  202.21875
# 1         [(649.03125, 198.13593, 886.0687, 476.49374)]  649.03125
# 2                   [(110.4375, 63.75, 575.25, 684.75)]  110.43750
# 3           [(0.5625, 217.40625, 404.15625, 559.96875)]    0.56250
# 4     [(51.1875, 218.625, 513.0, 651.375), (142.875,...  142.87500
# ...                                                 ...        ...
# 9907                    [(13.5, 58.125, 722.25, 837.0)]   13.50000
# 9908             [(218.0625, 169.875, 669.75, 725.625)]  218.06250
# 9909                       [(0.0, 12.95, 629.4, 889.0)]    0.00000
# 9910                 [(228.1875, 148.5, 660.75, 772.5)]  228.18750
# 9911             [(149.53125, 69.5625, 482.25, 630.75)]  149.53125
#
#            x_max       y_min       y_max  pet_ratio
# 0      32.062500  114.750000  229.218750   0.346914
# 1     886.068726  198.135925  476.493744   0.082485
# 2     575.250000   63.750000  684.750000   0.417773
# 3     404.000000  217.406250  559.968750   0.473827
# 4     513.000000  218.625000  377.625000   0.558559
# ...          ...         ...         ...        ...
# 9907  722.250000   58.125000  837.000000   0.731964
# 9908  669.750000  169.875000  725.625000   0.362784
# 9909  629.400024   12.950000  889.000000   0.884572
# 9910  660.750000  148.500000  772.500000   0.390000
# 9911  482.250000   69.562500  630.750000   0.360365
#
# [9912 rows x 23 columns]

# %%
FEATURES = [
        'Subject Focus', 
        'Eyes', 
        'Face', 
        'Near', 
        'Action', 
        'Accessory', 
        'Group', 
        'Collage', 
        'Human', 
        'Occlusion', 
        'Info', 
        'Blur'
    ]
TARGET = 'Pawpularity'

# %%
# seperate dog and cat analysis
dog = train.loc[train['label'] == 'dog']
dog
# Out:
#                                     Id  Subject Focus  Eyes  Face  Near  \
# 0     0007de18844b0dbbb5e1f607da0606e0              0     1     1     1
# 2     0013fd999caf9a3efe1352ca1b0d937e              0     1     1     1
# 3     0018df346ac9c1d8413cfcc888ca8246              0     1     1     1
# 4     001dc955e10590d3ca4673f034feeef2              0     0     0     1
# 5     001dd4f6fafb890610b1635f967ea081              0     0     1     0
# ...                                ...            ...   ...   ...   ...
# 9903  ff903858a9899465ee4cd17e942bef24              0     1     1     0
# 9904  ff9b3b3468c4b35a3b6450a1ddc88449              0     1     1     1
# 9908  ffcc8532d76436fc79e50eb2e5238e45              0     1     1     1
# 9910  fff19e2ce11718548fa1c5d039a5192a              0     1     1     1
# 9911  fff8e47c766799c9e12f3cb3d66ad228              0     1     1     1
#
#       Action  Accessory  Group  Collage  Human  ...  Pawpularity  \
# 0          0          0      1        0      0  ...           63
# 2          0          0      0        0      1  ...           28
# 3          0          0      0        0      0  ...           15
# 4          0          0      1        0      0  ...           72
# 5          0          0      0        0      0  ...           74
# ...      ...        ...    ...      ...    ...  ...          ...
# 9903       0          0      0        0      1  ...           51
# 9904       0          0      0        0      0  ...           44
# 9908       0          0      0        0      0  ...           70
# 9910       0          0      0        0      1  ...           20
# 9911       0          0      0        0      0  ...           30
#
#                                               file_path  n_pets  label  \
# 0     /kaggle/input/petfinder-pawpularity-score/trai...       3    dog
# 2     /kaggle/input/petfinder-pawpularity-score/trai...       1    dog
# 3     /kaggle/input/petfinder-pawpularity-score/trai...       1    dog
# 4     /kaggle/input/petfinder-pawpularity-score/trai...       2    dog
# 5     /kaggle/input/petfinder-pawpularity-score/trai...       1    dog
# ...                                                 ...     ...    ...
# 9903  /kaggle/input/petfinder-pawpularity-score/trai...       1    dog
# 9904  /kaggle/input/petfinder-pawpularity-score/trai...       1    dog
# 9908  /kaggle/input/petfinder-pawpularity-score/trai...       1    dog
# 9910  /kaggle/input/petfinder-pawpularity-score/trai...       1    dog
# 9911  /kaggle/input/petfinder-pawpularity-score/trai...       1    dog
#
#                                                  coords       x_min  \
# 0     [(120.58594, 114.75, 325.125, 474.75), (202.21...  202.218750
# 2                   [(110.4375, 63.75, 575.25, 684.75)]  110.437500
# 3           [(0.5625, 217.40625, 404.15625, 559.96875)]    0.562500
# 4     [(51.1875, 218.625, 513.0, 651.375), (142.875,...  142.875000
# 5                  [(179.625, 333.375, 439.5, 541.125)]  179.625000
# ...                                                 ...         ...
# 9903             [(163.59375, 168.5625, 525.75, 510.0)]  163.593750
# 9904       [(77.987114, 9.264453, 432.03946, 603.9422)]   77.987114
# 9908             [(218.0625, 169.875, 669.75, 725.625)]  218.062500
# 9910                 [(228.1875, 148.5, 660.75, 772.5)]  228.187500
# 9911             [(149.53125, 69.5625, 482.25, 630.75)]  149.531250
#
#            x_max       y_min      y_max  pet_ratio
# 0      32.062500  114.750000  229.21875   0.346914
# 2     575.250000   63.750000  684.75000   0.417773
# 3     404.000000  217.406250  559.96875   0.473827
# 4     513.000000  218.625000  377.62500   0.558559
# 5     439.500000  333.375000  541.12500   0.104321
# ...          ...         ...        ...        ...
# 9903  525.750000  168.562500  510.00000   0.179115
# 9904  432.039459    9.264453  603.94220   0.667283
# 9908  669.750000  169.875000  725.62500   0.362784
# 9910  660.750000  148.500000  772.50000   0.390000
# 9911  482.250000   69.562500  630.75000   0.360365
#
# [4593 rows x 23 columns]

# %%
import seaborn as sns
fig, axes = plt.subplots(nrows=3, ncols=4, figsize=(12, 8))

for f, ax in zip(FEATURES, axes.flatten()):
    sns.histplot(
        data=dog,
        x=TARGET,
        bins=30,
        hue=f,
        legend=True,
        kde=True,
        ax=ax,
        alpha=0.3)

fig.tight_layout()    
plt.show()

# %%
cat = train.loc[train['label'] == 'cat']
cat
# Out:
#                                     Id  Subject Focus  Eyes  Face  Near  \
# 1     0009c66b9439883ba2750fb825e1d7db              0     1     1     0
# 8     0042bc5bada6d1cf8951f8f9f0d399fa              0     1     1     1
# 9     0049cb81313c94fa007286e9039af910              0     1     1     1
# 10    005017716086b8d5e118dd9fe26459b1              0     1     1     1
# 12    00630b1262efe301cb15a3b2022ba744              0     1     1     1
# ...                                ...            ...   ...   ...   ...
# 9902  ff78a56d5e0029cd6288c62f7b7f10e5              0     1     1     1
# 9905  ffaf7bf7e64b9eecaf02fc2c14d6b654              0     1     1     1
# 9906  ffb8b466494a3e48bcb874a2fe9b976d              0     1     1     1
# 9907  ffbfa0383c34dc513c95560d6e1fdb57              0     0     0     1
# 9909  ffdf2e8673a1da6fb80342fa3b119a20              0     1     1     1
#
#       Action  Accessory  Group  Collage  Human  ...  Pawpularity  \
# 1          0          0      0        0      0  ...           42
# 8          0          0      0        0      0  ...           53
# 9          0          0      0        0      0  ...           21
# 10         0          0      0        0      0  ...           28
# 12         0          0      0        0      0  ...           18
# ...      ...        ...    ...      ...    ...  ...          ...
# 9902       0          0      0        0      0  ...           50
# 9905       0          0      0        0      0  ...           31
# 9906       0          0      0        0      0  ...           31
# 9907       0          0      0        0      0  ...           15
# 9909       0          0      0        0      1  ...           20
#
#                                               file_path  n_pets  label  \
# 1     /kaggle/input/petfinder-pawpularity-score/trai...       1    cat
# 8     /kaggle/input/petfinder-pawpularity-score/trai...       1    cat
# 9     /kaggle/input/petfinder-pawpularity-score/trai...       1    cat
# 10    /kaggle/input/petfinder-pawpularity-score/trai...       1    cat
# 12    /kaggle/input/petfinder-pawpularity-score/trai...       1    cat
# ...                                                 ...     ...    ...
# 9902  /kaggle/input/petfinder-pawpularity-score/trai...       1    cat
# 9905  /kaggle/input/petfinder-pawpularity-score/trai...       1    cat
# 9906  /kaggle/input/petfinder-pawpularity-score/trai...       1    cat
# 9907  /kaggle/input/petfinder-pawpularity-score/trai...       1    cat
# 9909  /kaggle/input/petfinder-pawpularity-score/trai...       1    cat
#
#                                               coords       x_min        x_max  \
# 1      [(649.03125, 198.13593, 886.0687, 476.49374)]  649.031250   886.068726
# 8                   [(1.875, 5.25, 656.625, 953.25)]    1.875000   656.625000
# 9     [(9.9921875, 2.8289056, 1231.0375, 842.67224)]    9.992188  1231.037476
# 10                   [(323.25, 74.5, 995.0, 1252.0)]  323.250000   995.000000
# 12            [(126.5625, 293.625, 510.75, 715.125)]  126.562500   510.750000
# ...                                              ...         ...          ...
# 9902                 [(539.0, 322.25, 909.0, 858.0)]  539.000000   909.000000
# 9905                   [(134.5, 0.0, 1276.0, 743.5)]  134.500000  1276.000000
# 9906  [(377.94922, 11.666992, 684.35547, 436.04688)]  377.949219   684.355469
# 9907                 [(13.5, 58.125, 722.25, 837.0)]   13.500000   722.250000
# 9909                    [(0.0, 12.95, 629.4, 889.0)]    0.000000   629.400024
#
#            y_min        y_max  pet_ratio
# 1     198.135925   476.493744   0.082485
# 8       5.250000   953.250000   0.898351
# 9       2.828906   842.672241   0.947538
# 10     74.500000  1252.000000   0.483164
# 12    293.625000   715.125000   0.312593
# ...          ...          ...        ...
# 9902  322.250000   858.000000   0.166242
# 9905    0.000000   743.500000   0.777134
# 9906   11.666992   436.046875   0.265639
# 9907   58.125000   837.000000   0.731964
# 9909   12.950000   889.000000   0.884572
#
# [5291 rows x 23 columns]

# %%
import seaborn as sns
fig, axes = plt.subplots(nrows=3, ncols=4, figsize=(12, 8))

for f, ax in zip(FEATURES, axes.flatten()):
    sns.histplot(
        data=cat,
        x=TARGET,
        bins=30,
        hue=f,
        legend=True,
        kde=True,
        ax=ax,
        alpha=0.3)

fig.tight_layout()    
plt.show()

# %% [markdown]
# # Plot Pet Photos

# %%
image_folder = '/kaggle/input/petfinder-pawpularity-score/train'
def plot_images(data, nrows=5, ncols=5, figsize=(15, 15)):

    indices = data.sample(nrows * ncols).index
    
    fig, axes = plt.subplots(nrows=nrows, ncols=ncols, figsize=figsize)
    for index, ax in zip(indices, axes.flatten()):
        img_path = os.path.join(image_folder, '{}.jpg'.format(index))
        img = Image.open(img_path)
        img = img.resize((128,128))
        ax.imshow(img)
        ax.set_title(train_df.loc[index][TARGET], fontsize=18)

    fig.tight_layout()
    plt.show()

# %%
pawpularity_range = [0, 20, 40, 60, 80, 100]
query = lambda i: '{} < Pawpularity and Pawpularity <= {}'.format(pawpularity_range[i], pawpularity_range[i+1])
for i in range(0, 5):
    df = train_df.query(query(i))
    plot_images(df, nrows=1, ncols=5, figsize=(12, 5))

# %% [markdown]
# # Using YOLOV5 to classify cats and dogs

# %%
# Hacky way of loading YOLOV5 offline, don't try this at home

# Add YOLOV5 master to cache
# !cp -R '/kaggle/input/yolov5/torch/root/.cache/torch' '/root/.cache/torch'
# Add Ultralytics (whatever this is) to the config folder
# !cp -R '/kaggle/input/yolov5/ultralytics/root/.config/Ultralytics' '/root/.config/Ultralytics'

# %%
# Load Best Performing YOLOV5X Model
yolov5x6_model = torch.hub.load('ultralytics/yolov5', 'yolov5x6')
# Out:
# Using cache found in /root/.cache/torch/hub/ultralytics_yolov5_master

# %%
self_test = pd.read_csv('/kaggle/input/590paw/test.csv')

# %%
self_test
# Out:
#                                 Id  true_label  \
# 0                     IMG_0969.JPG           0
# 1                     IMG_0982.JPG           1
# 2                     IMG_0983.JPG           1
# 3                     IMG_0968.JPG           0
# 4                     IMG_0981.JPG           1
# 5                     IMG_0980.JPG           1
# 6                     IMG_0984.JPG           1
# 7                     IMG_0985.JPG           1
# 8                     IMG_0978.JPG           0
# 9                     IMG_0979.JPG           1
# 10                WechatIMG829.JPG           0
# 11  pexels-anna-shvets-4587992.JPG           0
# 12                    IMG_7930.JPG           0
# 13                    IMG_0974.JPG           1
# 14                WechatIMG830.JPG           0
# 15                WechatIMG824.JPG           1
# 16                WechatIMG825.JPG           1
# 17                    IMG_0975.JPG           1
# 18                    IMG_0977.JPG           0
# 19                    IMG_9365.JPG           0
# 20                WechatIMG826.JPG           1
# 21                    IMG_0972.JPG           1
# 22                    IMG_0973.JPG           1
# 23                WechatIMG823.JPG           1
# 24                    IMG_0967.JPG           0
# 25                    IMG_0971.JPG           0
# 26                WechatIMG821.JPG           0
# 27                    IMG_8451.JPG           0
# 28                    IMG_0970.JPG           0
#
#                                             file_path
# 0                /kaggle/input/own-tests/IMG_0969.JPG
# 1                /kaggle/input/own-tests/IMG_0982.JPG
# 2                /kaggle/input/own-tests/IMG_0983.JPG
# 3                /kaggle/input/own-tests/IMG_0968.JPG
# 4                /kaggle/input/own-tests/IMG_0981.JPG
# 5                /kaggle/input/own-tests/IMG_0980.JPG
# 6                /kaggle/input/own-tests/IMG_0984.JPG
# 7                /kaggle/input/own-tests/IMG_0985.JPG
# 8                /kaggle/input/own-tests/IMG_0978.JPG
# 9                /kaggle/input/own-tests/IMG_0979.JPG
# 10           /kaggle/input/own-tests/WechatIMG829.JPG
# 11  /kaggle/input/own-tests/pexels-anna-shvets-458...
# 12               /kaggle/input/own-tests/IMG_7930.JPG
# 13               /kaggle/input/own-tests/IMG_0974.JPG
# 14           /kaggle/input/own-tests/WechatIMG830.JPG
# 15           /kaggle/input/own-tests/WechatIMG824.JPG
# 16           /kaggle/input/own-tests/WechatIMG825.JPG
# 17               /kaggle/input/own-tests/IMG_0975.JPG
# 18               /kaggle/input/own-tests/IMG_0977.JPG
# 19               /kaggle/input/own-tests/IMG_9365.JPG
# 20           /kaggle/input/own-tests/WechatIMG826.JPG
# 21               /kaggle/input/own-tests/IMG_0972.JPG
# 22               /kaggle/input/own-tests/IMG_0973.JPG
# 23           /kaggle/input/own-tests/WechatIMG823.JPG
# 24               /kaggle/input/own-tests/IMG_0967.JPG
# 25               /kaggle/input/own-tests/IMG_0971.JPG
# 26           /kaggle/input/own-tests/WechatIMG821.JPG
# 27               /kaggle/input/own-tests/IMG_8451.JPG
# 28               /kaggle/input/own-tests/IMG_0970.JPG

# %%
def get_pet_label(file_path):
    # Read Image
    image = imageio.imread(file_path)

    # Get YOLOV5 results using Test Time Augmentation for better result
    results = yolov5x6_model(image, augment=True)
   
    #plt.figure()
    #plt.imshow(image)
    # Save info for each pet
    for x1, y1, x2, y2, treshold, label_int in results.xyxy[0].cpu().detach().numpy():
        # Map integer encoded label to label
        label = results.names[int(label_int)]
        # Objects detected are already sorted on confidence, return first cat or dog
        if label in ['cat', 'dog']:
            return label
        
    # Could not detect pet, "unknown" label
    return 'unknown'

# %% [markdown]
# # Precitions

# %%
plot_df = self_test[20:]
plot_df
# Out:
#                   Id  true_label                                 file_path  \
# 20  WechatIMG826.JPG           1  /kaggle/input/own-tests/WechatIMG826.JPG
# 21      IMG_0972.JPG           1      /kaggle/input/own-tests/IMG_0972.JPG
# 22      IMG_0973.JPG           1      /kaggle/input/own-tests/IMG_0973.JPG
# 23  WechatIMG823.JPG           1  /kaggle/input/own-tests/WechatIMG823.JPG
# 24      IMG_0967.JPG           0      /kaggle/input/own-tests/IMG_0967.JPG
# 25      IMG_0971.JPG           0      /kaggle/input/own-tests/IMG_0971.JPG
# 26  WechatIMG821.JPG           0  /kaggle/input/own-tests/WechatIMG821.JPG
# 27      IMG_8451.JPG           0      /kaggle/input/own-tests/IMG_8451.JPG
# 28      IMG_0970.JPG           0      /kaggle/input/own-tests/IMG_0970.JPG
#
#    pred_label
# 20        cat
# 21        cat
# 22        cat
# 23        cat
# 24        dog
# 25        dog
# 26        dog
# 27        dog
# 28        dog

# %%
fig, axs = plt.subplots(3,3,figsize=(12, 8))
for idx, row in plot_df.iterrows(): 
    i = (idx-20)//3
    j = (idx-20) % 3
    file_path = row['file_path']
    image = imageio.imread(file_path)
    #image = np.resize(image,(128,128))
    axs[i,j].imshow(image)

# %%
# Submission dictionary to create DataFrame from
pred_label = []
for pet_id, file_path in tqdm(self_test[['Id', 'file_path']].itertuples(index=False), total=len(self_test)):
    label = get_pet_label(file_path)
    image = imageio.imread(file_path)    
    pred_label.append(label)
# Out:
#   0%|          | 0/29 [00:00<?, ?it/s]

# %%
self_test ['pred_label'] = pred_label

# %%
self_test
# Out:
#                                 Id  true_label  \
# 0                     IMG_0969.JPG           0
# 1                     IMG_0982.JPG           1
# 2                     IMG_0983.JPG           1
# 3                     IMG_0968.JPG           0
# 4                     IMG_0981.JPG           1
# 5                     IMG_0980.JPG           1
# 6                     IMG_0984.JPG           1
# 7                     IMG_0985.JPG           1
# 8                     IMG_0978.JPG           0
# 9                     IMG_0979.JPG           1
# 10                WechatIMG829.JPG           0
# 11  pexels-anna-shvets-4587992.JPG           0
# 12                    IMG_7930.JPG           0
# 13                    IMG_0974.JPG           1
# 14                WechatIMG830.JPG           0
# 15                WechatIMG824.JPG           1
# 16                WechatIMG825.JPG           1
# 17                    IMG_0975.JPG           1
# 18                    IMG_0977.JPG           0
# 19                    IMG_9365.JPG           0
# 20                WechatIMG826.JPG           1
# 21                    IMG_0972.JPG           1
# 22                    IMG_0973.JPG           1
# 23                WechatIMG823.JPG           1
# 24                    IMG_0967.JPG           0
# 25                    IMG_0971.JPG           0
# 26                WechatIMG821.JPG           0
# 27                    IMG_8451.JPG           0
# 28                    IMG_0970.JPG           0
#
#                                             file_path pred_label
# 0                /kaggle/input/own-tests/IMG_0969.JPG        dog
# 1                /kaggle/input/own-tests/IMG_0982.JPG        cat
# 2                /kaggle/input/own-tests/IMG_0983.JPG        cat
# 3                /kaggle/input/own-tests/IMG_0968.JPG        dog
# 4                /kaggle/input/own-tests/IMG_0981.JPG        cat
# 5                /kaggle/input/own-tests/IMG_0980.JPG        cat
# 6                /kaggle/input/own-tests/IMG_0984.JPG        cat
# 7                /kaggle/input/own-tests/IMG_0985.JPG        cat
# 8                /kaggle/input/own-tests/IMG_0978.JPG        dog
# 9                /kaggle/input/own-tests/IMG_0979.JPG        cat
# 10           /kaggle/input/own-tests/WechatIMG829.JPG        dog
# 11  /kaggle/input/own-tests/pexels-anna-shvets-458...        dog
# 12               /kaggle/input/own-tests/IMG_7930.JPG        dog
# 13               /kaggle/input/own-tests/IMG_0974.JPG        cat
# 14           /kaggle/input/own-tests/WechatIMG830.JPG        dog
# 15           /kaggle/input/own-tests/WechatIMG824.JPG        cat
# 16           /kaggle/input/own-tests/WechatIMG825.JPG        cat
# 17               /kaggle/input/own-tests/IMG_0975.JPG        cat
# 18               /kaggle/input/own-tests/IMG_0977.JPG        dog
# 19               /kaggle/input/own-tests/IMG_9365.JPG        dog
# 20           /kaggle/input/own-tests/WechatIMG826.JPG        cat
# 21               /kaggle/input/own-tests/IMG_0972.JPG        cat
# 22               /kaggle/input/own-tests/IMG_0973.JPG        cat
# 23           /kaggle/input/own-tests/WechatIMG823.JPG        cat
# 24               /kaggle/input/own-tests/IMG_0967.JPG        dog
# 25               /kaggle/input/own-tests/IMG_0971.JPG        dog
# 26           /kaggle/input/own-tests/WechatIMG821.JPG        dog
# 27               /kaggle/input/own-tests/IMG_8451.JPG        dog
# 28               /kaggle/input/own-tests/IMG_0970.JPG        dog

# %%
count_df = self_test.groupby(['pred_label'])['pred_label'].count()
count_df = count_df.to_frame()
count_df = count_df.rename(columns={"pred_label": "label", "pred_label": "counts"})
count_df = count_df.reset_index()
count_df
# Out:
#   pred_label  counts
# 0        cat      15
# 1        dog      14

# %%
import plotly.graph_objects as go

labels = count_df['pred_label'] 
#values = [4500, 2500, 1053, 500]

# Use `hole` to create a donut-like pie chart
fig = go.Figure(data=[go.Pie(labels=count_df['pred_label'] , 
                             values=count_df['counts'], 
                             hole=.70)])
fig.update_layout(
    #autosize=False,
    width=600,
    height=400,
    title="Pie Graph for Cats and Dogs Counts"
)

fig.show()
# Out:
# <div>                            <div id="bf48330b-6427-431c-8a77-7e2d92b01ca0" class="plotly-graph-div" style="height:400px; width:600px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bf48330b-6427-431c-8a77-7e2d92b01ca0")) {                    Plotly.newPlot(                        "bf48330b-6427-431c-8a77-7e2d92b01ca0",                        [{"hole":0.7,"labels":["cat","dog"],"type":"pie","values":[15,14]}],                        {"height":400,"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter3d"}],"scattercarpet":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scattercarpet"}],"scattergeo":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter ...
#
# var gd = document.getElementById('bf48330b-6427-431c-8a77-7e2d92b01ca0');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'remove

# %%
self_test.to_csv('yolov5.csv')
